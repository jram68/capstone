# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    #print '%d:"%s"'(i,name)
    col.append((name,[]))

# %%
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %% [markdown]
# check the length of each column for uniformity and to catch errors

# %%
[len(C) for (title,C) in col]
# Out:
# [289, 289, 289]

# %% [markdown]
# create dictionary and pandas dataframe

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %% [markdown]
# look at the top few row of the dataframe to see how it looks

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %% [markdown]
# clean up the dataset

# %%
df = df[df.Borough != 'Not assigned']

# %%
df.replace(r'\n', '', regex = True, inplace = True)

# %%
df.rename(columns = {'Neighbourhood\n':'Neighbourhood'}, inplace = True)

# %%
df10 = df

# %%
df11 = df10.groupby('Postcode').agg({'Borough' : 'sum', 'Neighbourhood': lambda x: ', '.join(x)})

# %%
df11['Borough'] = df11['Borough'].replace({'EtobicokeEtobicoke':'Etobicoke', 
                                           'EtobicokeEtobicokeEtobicoke':'Etobicoke', 
                                           'EtobicokeEtobicokeEtobicokeEtobicoke':'Etobicoke', 
                                           'EtobicokeEtobicokeEtobicokeEtobicokeEtobicoke':'Etobicoke', 
                                           'EtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicoke':'Etobicoke',
                                           'EtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicoke':'Etobicoke',
                                           'EtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicokeEtobicoke':'Etobicoke',
                                           'North YorkNorth York':'North York', 
                                           'North YorkNorth YorkNorth York':'North York', 'YorkYorkYorkYork':'York', 'YorkYork':'York', 
                                           'West TorontoWest Toronto':'West Toronto', 'West TorontoWest TorontoWest Toronto':'West Toronto',
                                          'ScarboroughScarboroughScarboroughScarborough':'Scarborough', 'ScarboroughScarboroughScarborough':'Scarborough',
                                          'ScarboroughScarborough':'Scarborough'})

# %%
df11
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M1B            Scarborough                                     Rouge, Malvern
# M1C            Scarborough             Highland Creek, Rouge Hill, Port Union
# M1E            Scarborough                  Guildwood, Morningside, West Hill
# M1G            Scarborough                                             Woburn
# M1H            Scarborough                                          Cedarbrae
# M1J            Scarborough                                Scarborough Village
# M1K            Scarborough        East Birchmount Park, Ionview, Kennedy Park
# M1L            Scarborough                    Clairlea, Golden Mile, Oakridge
# M1M            Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# M1N            Scarborough                        Birch Cliff, Cliffside West
# M1P            Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# ...

# %%
df11.shape
# Out:
# (103, 2)
